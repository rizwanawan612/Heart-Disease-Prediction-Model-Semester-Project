# %%
# Import the dependencies
# Ignore warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# %matplotlib inline

# %%
# Import seaborn

import seaborn as sns

# %%
# loading dataset
df=pd.read_csv('D:/MS DS/TT for DS Theory/data set of cardio disease/heart_statlog_cleveland_hungary_final.csv')
#df=data.copy()
df.head()
# Out:
#    age  sex  chest pain type  resting bps  cholesterol  fasting blood sugar  \
# 0   40    1                2          140          289                    0
# 1   49    0                3          160          180                    0
# 2   37    1                2          130          283                    0
# 3   48    0                4          138          214                    0
# 4   54    1                3          150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bps          1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
# Set the plot styles with set() method
sns.set_style("white")
sns.set()

# %%
sns.distplot(df['age']) 
plt.show()

# %%
sns.distplot(df['chest pain type']) 
plt.show()

# %%
sns.distplot(df['resting bps']) 
plt.show()

# %%
sns.distplot(df['cholesterol']) 
plt.show()

# %%
sns.lineplot(data=df,x='age', y='cholesterol', style='target', lw=10, color='red', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='cholesterol'>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bps', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
sns.distplot(df['max heart rate']) 
plt.show()

# %%
sns.distplot(df['max heart rate'], color='green', kde=False) 

plt.show()

# %%
sns.distplot(df['max heart rate'], color='green', kde=True) 

plt.show()

# %%
#In seaborn, the hue parameter determines which column in the data frame should be used for colour encoding
sns.set_style('white')
sns.relplot(x='age',y='max heart rate', data=df, kind='line' , hue='target', col='sex')

# %%
#sns.distplot(tips['cholesterol'])
#shade, Bw, 
sns.kdeplot(df['cholesterol'], shade=True, bw=1) 

plt.show()

# %%
sns.kdeplot(df['age'],df['cholesterol'], shade=True, bw=1) 

plt.show()

# %%
sns.jointplot(x="age", y="cholesterol", data=df)
plt.show()

# %%
sns.jointplot(x="age", y="max heart rate", data=df)
plt.show()

# %%
#hue='target', size="sex"

sns.scatterplot(x="age", y="max heart rate", data=df, size="sex",hue='target')

plt.show()

# %%
#diag_kind='kde' to change the plots on the diagnol and to change the off diagnol plots use (kind='reg')
# hue can also be set to day, target, sex etc.
sns.set_style("darkgrid")

sns.pairplot(df)

plt.show()

# %%
df.dtypes
# Out:
# age                      int64
# sex                      int64
# chest pain type          int64
# resting bps              int64
# cholesterol              int64
# fasting blood sugar      int64
# resting ecg              int64
# max heart rate           int64
# exercise angina          int64
# oldpeak                float64
# ST slope                 int64
# target                   int64
# dtype: object

# %%
#relplot()
#scatterplot()
#lineplot()
sns.relplot(data= df,x='age',y='max heart rate',hue='target')

# %%
sns.stripplot(x="chest pain type", y="cholesterol", data=df)

plt.show()

# %%
sns.swarmplot(x="ST slope", y="resting bps", data=df)

plt.show()
# Out:
# C:\Users\CR-COMPUTERS\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\CR-COMPUTERS\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(y=df["age"])

plt.show()

# %%
sns.boxplot(x="chest pain type", y="age", data=df)

plt.show()

# %%
sns.violinplot(x=df["resting bps"])

plt.show()

# %%
# hue='sex', split=True, inner='quartiles'(25th, 50th,75th quartiles), color='yellow'
# scaling based on the count: scale='count'
sns.violinplot(x="chest pain type", y="age", data=df)

plt.show()

# %%
# counts the number of male and female in the df dataset
df['sex'].value_counts()
# Out:
# 1    909
# 0    281
# Name: sex, dtype: int64

# %%
sns.barplot(x="chest pain type", y="cholesterol", data=df)

plt.show()

# %%
sns.pointplot(x="target", y="cholesterol", data=df)

plt.show()

# %%
sns.pointplot(x="target", y="cholesterol", hue="exercise angina", data=df)

plt.show()

# %%
sns.pointplot(x="target", y="resting bps", hue="fasting blood sugar", data=df)

plt.show()

# %%
sns.stripplot(x="target", y="age", hue="sex", data=df)

plt.show()

# %%
sns.regplot(x="age", y="max heart rate", data=df)

plt.show()

# %%
sns.lmplot(x="age", y="max heart rate", data=df)

plt.show()

# %%
sns.residplot(x="age", y="max heart rate", data=df)

plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.figure(figsize=(20,30))
plt.show()

# %%
print(df.corr())
# Out:
#                           age       sex  chest pain type  resting bps  \
# age                  1.000000  0.015096         0.149055     0.257692
# sex                  0.015096  1.000000         0.138405    -0.006443
# chest pain type      0.149055  0.138405         1.000000     0.009466
# resting bps          0.257692 -0.006443         0.009466     1.000000
# cholesterol         -0.046472 -0.208441        -0.109396     0.099037
# fasting blood sugar  0.178923  0.110961         0.076492     0.088235
# resting ecg          0.194595 -0.022225         0.035705     0.095860
# max heart rate      -0.368676 -0.181837        -0.337491    -0.101357
# exercise angina      0.188095  0.194380         0.403428     0.142435
# oldpeak              0.245093  0.096390         0.224106     0.176111
# ST slope             0.237749  0.127913         0.276949     0.089384
# target               0.262029  0.311267         0.460127     0.121415
#
# ...

# %%
df1 = df[['age', 'resting bps', 'cholesterol']]

# %%
sns.clustermap(df1)

plt.show()

# %%
g = sns.FacetGrid(df, col="ST slope",  row="sex", hue='target')
g.map(sns.scatterplot, "age", "resting bps")

# %%
#hue='sex'
g = sns.FacetGrid(df, col="ST slope",  row="target")

g = g.map(plt.hist, "age")

plt.show()

# %%
g = sns.PairGrid(df)

g = g.map(plt.scatter)

plt.show()

# %%
g = sns.PairGrid(df)

g = g.map_diag(plt.hist)

g = g.map_offdiag(plt.scatter)

# %%
g = sns.JointGrid(x="age", y="resting bps", data=df)

g = g.plot(sns.regplot, sns.distplot)
